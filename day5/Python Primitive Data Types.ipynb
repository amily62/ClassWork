# %%
a=10
b=-5
c=a+b
print(c)
# Out:
# 5

# %%
pi=3.13159
r=5.0
area= pi*(r**2)
print(area)
# Out:
# 78.28975

# %%
name="Alice"
greeting=f"Hello,{name}"
print(greeting)
# Out:
# Hello,Alice

# %%
is_valid= True
if is_valid:
  print("Data is valid")
# Out:
# Data is valid

# %%
result= None
if result is None:
  print("No result Avaiable")
# Out:
# No result Avaiable
