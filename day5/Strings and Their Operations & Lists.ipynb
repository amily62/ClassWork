# %%
text= "python programming"
first_letter=text[0]
substring=text[7:18]
print(f"first_letter= {first_letter}\nsubstring= {substring}")
# Out:
# first_letter= p
# substring= programming

# %%
text="Hello World"
upper_text = text.upper()
replace_text= text.replace("World","Python")
print(f"upper_text= {upper_text}\nreplace_text= {replace_text}")
# Out:
# upper_text= HELLO WORLD
# replace_text= Hello Python

# %%
list = ["apple","banana","mango"]
first_fruit = list[0]
print(f"first_fruit= {first_fruit}")
# Out:
# first_fruit= apple

# %%
list = ["apple", "banana", "mango"]
list.append("Orange")
print("\n new list: ",list)
list.remove("banana")
print("\nUpdated list:", list)
# Out:
#  new list:  ['apple', 'banana', 'mango', 'Orange']
#
# Updated list: ['apple', 'mango', 'Orange']

# %%
squares=[x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]
