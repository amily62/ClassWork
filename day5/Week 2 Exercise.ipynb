# %%
"""   Create a list of your favorite five movies. Write a program to:
• Print the second movie in the list.
• Add a new movie to the end of the list.
• Remove the first movie from the list and print the updated list. """

movies = ["Titanic","Avatar","The Matrix","Black Panther","The Lion King"]
print("The second movie:", movies[1])
print("\n Movie list of movies:", movies)
movies.append("Frozen II")
movies.pop(0)
print("\n Updated list of movies:", movies)
# Out:
# The second movie: Avatar
#
#  Movie list of movies: ['Titanic', 'Avatar', 'The Matrix', 'Black Panther', 'The Lion King']
#
#  Updated list of movies: ['Avatar', 'The Matrix', 'Black Panther', 'The Lion King', 'Frozen II']

# %%
"""   Dictionary Operations: Write a program to create a dictionary that stores information about a book (title,
author, year, and genre). Then:
• Print the title of the book.
• Update the year to the current year and print the updated dictionary.  """

books={
    "title": "Pyhton programing",
    "Author": "Mr.X",
    "year": 2015,
    "genre":"writers"
}
print("The title of the book: ", books["title"])
import datetime
year1 = datetime.datetime.now().year
books["year"] = year1
print("\nThe update dictionary: ", books)
# Out:
# The title of the book:  Pyhton programing
#
# The update dictionary:  {'title': 'Pyhton programing', 'Author': 'Mr.X', 'year': 2024, 'genre': 'writers'}

# %%
"""  Set Operations: Create two sets: set A = {1, 2, 3, 4, 5} and set B = {4, 5, 6, 7, 8}. Write a program
to:
•Find and print the symmetric difference of the two sets. """


a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
c= a.difference(b)
d= b.difference(a)
e = c.union(d)
print("The symmetric diffrence between a and b is: ",e)
# Out:
# The symmetric diffrence between a and b is:  {1, 2, 3, 6, 7, 8}

# %%
"""Tuple Unpacking: Create a tuple with three different data types (e.g., string, integer, float). Write a program
that:
• Unpacks the tuple into three variables and prints each variable separately."""
tupple1= ("Pyhton",12,17.5)
str_var, int_var, float_var =tupple1
print(f"str_var= {str_var} \nint_var= {int_var} \nfloat_var= {float_var}")
# Out:
# str_var= Pyhton
# int_var= 12
# float_var= 17.5

# %%
"""   String Formatting: Write a program that takes the user’s first name and last name as input and prints a
message in the format: “Hello, [First Name] [Last Name]! Welcome to Python programming.  """

frsit_name = input("Enter your 1st name: ")
last_name = input("Enter your Last name: ")

print(f"Hello, {frsit_name} {last_name}! Welcome to Python programming")
# Out:
# Enter your 1st name: Mahmudul
# Enter your Last name: Hasan
# Hello, Mahmudul  Hasan! Welcome to Python programming
