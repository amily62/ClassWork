# %%
"""Write a Python Program to get a Number from User to Display Its Next and
Previous Numbers. If User Enter ‘4’, System Should Display 5 as Next Number
and 3 as Pervious Number."""
num=int(input("enter a number: "))
num1=num
num2=num
num1 += 1
num2 -=  1
print(f"{num1} as Next Number and {num2} as Pervious Number")
# Out:
# enter a number: 7
# 8 as Next Number and 6 as Pervious Number

# %%
"""Write a Python Program to get Two Numbers from User, Find Square of First
Number and Cube Of 2nd Number. Then Find Their Sum."""
num=int(input("enter a number: "))
num1=int(input("enter a number: "))
num= num**2
num1=num1**3
print(f"Square of First Number is {num} and Cube Of 2nd Number is {num1}")
# Out:
# enter a number: 5
# enter a number: 3
# Square of First Number is 25 and Cube Of 2nd Number is 27
