# %%
"""Write a Python Program to get name of user and Display user name in uppercase."""
name= input("enter your name: ")
name1= name.upper()
print(name1)
# Out:
# enter your name: swarno
# SWARNO

# %%
"""Write a Python Program to get age of user and convert into seconds."""
age= int(input("enter your age in year: "))
age1=age*365*24*60*60
print("Your age in seconds: ",age1)
# Out:
# enter your age in year: 22
# Your age in seconds:  693792000

# %%
"""Write a Python Program to get Three Numbers from User to Increase One Value to
Every Number."""
num1=int(input("enter a number: "))
num2=int(input("enter a number: "))
num3=int(input("enter a number: "))
num1 += 1
num2 += 1
num3 += 1
print(f"1st number: {num1} \n2nd number: {num2} \n3rd number: {num3}")
# Out:
# enter a number: 78
# enter a number: 6
# enter a number: 5
# 1st number: 79
# 2nd number: 7
# 3rd number: 6

# %%
"""Write a Python Program to get a Number from User to Find Square of that Number
and then Display Result."""
num= int(input("enter a number: "))
num1= num**2
print("th square of the number: ",num1)
# Out:
# enter a number: 5
# th square pf the number:  25

# %%
"""Write a Python Program to get 3 Numbers from User, Multiply 1st and 3rd Numbesr
and then Add 2nd Number to Resultant."""

num1=int(input("enter a number: "))
num2 =int(input("enter a number: "))
num3=int(input("enter a number: "))
num2=int(input("enter a number: "))
num3=int(input("enter a number: "))
mul= num1*num3
result= mul + num2
print("The result is : ",result)
# Out:
# enter a number: 4
# enter a number: 8
# enter a number: 9
# The result is :  44
