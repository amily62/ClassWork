# %%
"""string template"""
from string import Template
str ='Hi $name, your age is $age'
template_obj = Template(str)
template_obj.substitute(name='Mahmudul Hasan', age=24)
# Out:
# 'Hi Mahmudul Hasan, you age is 24'

# %%
"""Write a Python Program to Get First Name, Last Name, Email Address
and Contact Number from User and Format String in Different Styles."""


first_name=input("Enter your first name: ")
last_name=input("Enter your last name: ")
email=input("Enter your email address: ")
contact_number=input("Enter your contact number: ")
print("Detail Information:________________________________________")
print(f"Full Name= {first_name} {last_name}")
print(f"Email= {email}")
print(f"Contact= {contact_number}")
# Out:
# Enter your first name: Mahmudul
# Enter your last name: Hasan
# Enter your email address: yusafafd@gmail.com
# Enter your contact number: 0175436436664
# Detail Information:________________________________________
# Full Name= Mahmudul Hasan
# Email= yusafafd@gmail.com
# Contact= 0175436436664

# %%
"""Write a Python Program to Get Three Subjects Marks and Format
Marks in a String and Display Total Marks and Average also in a String (as
follows).

Hi, Your marks in Physics = “Number”, Chemistry = “Number”, Math = “Number”.
And Your Total Marks is bla bla and Average is bla bla."""

physics= float(input("Enter your physics mark:"))
chemistry= float(input("Enter your chemistry mark:"))
math= float(input("Enter your math mark:"))
total_mark= physics + chemistry+math
avg= total_mark / 3
print(f"Hi, Your marks in Physics = {physics}, Chemistry = {chemistry}, Math = {math}.And Your Total Marks is {total_mark} and Average is {avg}.")
# Out:
# Enter your physics mark:78
# Enter your chemistry mark:83
# Enter your math mark:71
# Hi, Your marks in Physics = 78.0, Chemistry = 83.0, Math = 71.0.And Your Total Marks is 232.0 and Average is 77.33333333333333.

# %%
from numpy import*
arr=array([])
for i in range(5):
  v=input("Elemet: ")
  arr=append(arr,v)
print(arr)
# Out:
# Elemet: 5
# Elemet: 7
# Elemet: 4
# Elemet: 8
# Elemet: 9
# ['5' '7' '4' '8' '9']
